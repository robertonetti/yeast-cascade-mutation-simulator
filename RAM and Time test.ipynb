# %% [markdown]
# # RAM Usage and Time Elapsed Test

# %%
from code.Parameters import *
from code.Simulator import Simulator
from code.Utility import Utility
import matplotlib.pyplot as plt
import time as tm

# %%
tool = Utility()

n_generations_to_test = 12 # set the max number of generation we want to simulate

times = []
mem = []

# repeat from 1 generations to 'n_generations_to_test'
for n_g in range(n_generations_to_test):
    print(f"Number of generations: {n_g}")

    # simulation
    simul = Simulator(chromosome_table, n_g, average_events_number, cumulative_list, \
                n_events_distrib, del_len_distrib, ins_len_distrib, transl_len_distrib, dupl_len_distrib )

    # reconstruction and time
    start = tm.time()
    simul.reconstructor(simul.parent, n_g, chromosome_table)
    times.append(tm.time() - start)

    # compute memeory
    tot_mem, py_mem = tool.mem_count()
    mem.append(py_mem)

    print(f"total memory: {tot_mem} Mb \npython memory: {py_mem} Mb \n")
# Out:
# Number of generations: 0
# total memory: 10645.79296875 Mb
# python memory: 209.0 Mb
#
# Number of generations: 1
# total memory: 10640.83203125 Mb
# python memory: 216.0 Mb
#
# Number of generations: 2
# total memory: 10611.828125 Mb
# python memory: 222.0 Mb
#
# Number of generations: 3
# total memory: 10614.7578125 Mb
# python memory: 249.0 Mb
#
# Number of generations: 4
# total memory: 10647.55078125 Mb
# python memory: 288.0 Mb
#
# Number of generations: 5
# total memory: 10811.00390625 Mb
# python memory: 392.0 Mb
#
# Number of generations: 6
# total memory: 10970.94921875 Mb
# python memory: 540.0 Mb
#
# Number of generations: 7
# total memory: 11144.58984375 Mb
# python memory: 873.0 Mb
#
# Number of generations: 8
# total memory: 11824.6484375 Mb
# python memory: 1539.0 Mb
#
# Number of generations: 9
# total memory: 13265.7109375 Mb
# python memory: 2939.0 Mb
#
# Number of generations: 10
# total memory: 16171.4921875 Mb
# python memory: 5715.0 Mb
#
# Number of generations: 11
# total memory: 21567.6171875 Mb
# python memory: 11381.0 Mb

# %%
# Plot of the Elapsed Time
plt.plot(range(n_generations_to_test), times, "*-")
plt.xlabel("No. generations")
plt.ylabel("Time (sec)")
plt.title("Reconstruction time")
plt.grid(True)
plt.show()

# %%
# Plot of the RAM Usage
plt.plot(range(n_generations_to_test), mem, "*-")
plt.xlabel("No. generations")
plt.ylabel("RAM usage (Mb)")
plt.title("RAM usage for Reconstruction")
plt.grid(True)
plt.show()
