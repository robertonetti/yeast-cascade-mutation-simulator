# %% [markdown]
# # RAM Usage and Time Elapsed Test

# %%
from code.Parameters import *
from code.Simulator import Simulator
from code.Utility import Utility
import matplotlib.pyplot as plt
import time as tm

# %%
tool = Utility()

n_generations_to_test = 12 # set the max number of generation we want to simulate

times = []
mem = []

# repeat from 1 generations to 'n_generations_to_test'
for n_g in range(n_generations_to_test):
    print(f"Number of generations: {n_g}")

    # simulation
    simul = Simulator(chromosome_table, n_g, average_events_number, cumulative_list, \
                n_events_distrib, del_len_distrib, ins_len_distrib, transl_len_distrib, dupl_len_distrib )

    # reconstruction and time
    start = tm.time()
    simul.reconstructor(simul.parent, n_g, chromosome_table)
    times.append(tm.time() - start)

    # compute memeory
    tot_mem, py_mem = tool.mem_count()
    mem.append(py_mem)

    print(f"total memory: {tot_mem} Mb \npython memory: {py_mem} Mb \n")
# Out:
# Number of generations: 0
# total memory: 10707.6875 Mb
# python memory: 214.0 Mb
#
# Number of generations: 1
# total memory: 10712.2734375 Mb
# python memory: 218.0 Mb
#
# Number of generations: 2
# total memory: 10731.12890625 Mb
# python memory: 226.0 Mb
#
# Number of generations: 3
# total memory: 10771.0 Mb
# python memory: 233.0 Mb
#
# Number of generations: 4
# total memory: 10812.36328125 Mb
# python memory: 260.0 Mb
#
# Number of generations: 5
# total memory: 10884.43359375 Mb
# python memory: 306.0 Mb
#
# Number of generations: 6
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-5c9ed5206ccf> in <module>
#      16     # reconstruction and time
#      17     start = tm.time()
# ---> 18     simul.reconstructor(simul.parent, n_g, chromosome_table)
#      19     times.append(tm.time() - start)
#      20
#
# ~/Desktop/Project/yeast-cascade-mutation-simulator/code/Simulator.py in reconstructor(self, parent, n_generations, chromosome_table)
#     475             gc.collect()
#     476         ##########################################
# --> 477             self.reconstructor(doughter1, n_generations, chromosome_table)
#     478             self.reconstructor(doughter2, n_generations, chromosome_table)
#     479
#
# ~/Desktop/Project/yeast-cascade-mutation-simulator/code/Simulator.py in reconstructor(self, parent, n_generations, chromosome_table)
#     475             gc.collect()
#     476         ##########################################
# --> 477             self.reconstructor(doughter1, n_generations, chromosome_table)
#     478             self.reconstructor(doughter2, n_generations, chromosome_table)
#     479
#
# ~/Desktop/Project/yeast-cascade-mutation-simulator/code/Simulator.py in reconstructor(self, parent, n_generations, chromosome_table)
#     475             gc.collect()
#     476         ##########################################
# --> 477             self.reconstructor(doughter1, n_generations, chromosome_table)
#     478             self.reconstructor(doughter2, n_generations, chromosome_table)
#     479
#
# ~/Desktop/Project/yeast-cascade-mutation-simulator/code/Simulator.py in reconstructor(self, parent, n_generations, chromosome_table)
#     475             gc.collect()
#     476         ##########################################
# --> 477             self.reconstructor(doughter1, n_generations, chromosome_table)
#     478             self.reconstructor(doughter2, n_generations, chromosome_table)
#     479
#
# ~/Desktop/Project/yeast-cascade-mutation-simulator/code/Simulator.py in reconstructor(self, parent, n_generations, chromosome_table)
#     476         ##########################################
#     477             self.reconstructor(doughter1, n_generations, chromosome_table)
# --> 478             self.reconstructor(doughter2, n_generations, chromosome_table)
#     479
#     480     def path_reconstructor(self, path: list, chromosome_table: list):
#
# ~/Desktop/Project/yeast-cascade-mutation-simulator/code/Simulator.py in reconstructor(self, parent, n_generations, chromosome_table)
#     473             for chr in parent.data.DNA.CHRs:
#     474                 del(chr.sequence)
# --> 475             gc.collect()
#     476         ##########################################
#     477             self.reconstructor(doughter1, n_generations, chromosome_table)
#
# KeyboardInterrupt:

# %%
# Plot of the Elapsed Time
plt.plot(range(n_generations_to_test), times, "*-")
plt.xlabel("No. generations")
plt.ylabel("Time (sec)")
plt.title("Reconstruction time")
plt.grid(True)
plt.show()

# %%
# Plot of the RAM Usage
plt.plot(range(n_generations_to_test), mem, "*-")
plt.xlabel("No. generations")
plt.ylabel("RAM usage (Mb)")
plt.title("RAM usage for Reconstruction")
plt.grid(True)
plt.show()
